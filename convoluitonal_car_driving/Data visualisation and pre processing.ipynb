# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('data/data2.csv')

# %%
images = data['image']

# %%
X_train = [ plt]

# %%
image = plt.imread(images[0])

# %%
plt.imshow(image)
